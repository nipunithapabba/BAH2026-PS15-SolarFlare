# %% [markdown]
# <a href="https://colab.research.google.com/github/nipunithapabba/BAH2026-PS15-SolarFlare/blob/main/notebooks/BAH2026_PS15_Starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive — run this every session
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
